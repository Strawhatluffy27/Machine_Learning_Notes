# %% [markdown]
# # Handling Csv Files

# %%
import pandas as pd

# %%
pd.read_csv(r"E:\assigiments in innomatric\parse error ml.txt",on_bad_lines = "skip")
# Out:
#   name  age
# 0   p1   25
# 1   p2   23

# %%
pd.read_csv(r"E:\assigiments in innomatric\parse error ml.txt",on_bad_lines = "warn")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_16540\608975540.py:1: ParserWarning: Skipping line 4: expected 2 fields, saw 3
#
#   pd.read_csv(r"E:\assigiments in innomatric\parse error ml.txt",on_bad_lines = "warn")
#   name  age
# 0   p1   25
# 1   p2   23

# %%
l = ["utf-8","latin","utf16"]

# %%
for y in l:
    try:
        pd.read_csv("spam.csv",encoding = y)
        print("{} is correctn encoding".format(y))
    except UnicodeDecodeError:
        print("{} is not encoding".format(y))
# Out:
# utf-8 is not encoding
# latin is correctn encoding
# utf16 is not encoding

# %%
import encodings

# %%
l =encodings.aliases.aliases.keys()

# %%
l
# Out:
# dict_keys(['646', 'ansi_x3.4_1968', 'ansi_x3_4_1968', 'ansi_x3.4_1986', 'cp367', 'csascii', 'ibm367', 'iso646_us', 'iso_646.irv_1991', 'iso_ir_6', 'us', 'us_ascii', 'base64', 'base_64', 'big5_tw', 'csbig5', 'big5_hkscs', 'hkscs', 'bz2', '037', 'csibm037', 'ebcdic_cp_ca', 'ebcdic_cp_nl', 'ebcdic_cp_us', 'ebcdic_cp_wt', 'ibm037', 'ibm039', '1026', 'csibm1026', 'ibm1026', '1125', 'ibm1125', 'cp866u', 'ruscii', '1140', 'ibm1140', '1250', 'windows_1250', '1251', 'windows_1251', '1252', 'windows_1252', '1253', 'windows_1253', '1254', 'windows_1254', '1255', 'windows_1255', '1256', 'windows_1256', '1257', 'windows_1257', '1258', 'windows_1258', '273', 'ibm273', 'csibm273', '424', 'csibm424', 'ebcdic_cp_he', 'ibm424', '437', 'cspc8codepage437', 'ibm437', '500', 'csibm500', 'ebcdic_cp_be', 'ebcdic_cp_ch', 'ibm500', '775', 'cspc775baltic', 'ibm775', '850', 'cspc850multilingual', 'ibm850', '852', 'cspcp852', 'ibm852', '855', 'csibm855', 'ibm855', '857', 'csibm857', 'ibm857', '858', 'csibm858', 
# ...

# %%
l1 =[]
for y in l:
    try:
        pd.read_csv("spam.csv",encoding = y, on_bad_lines = "skip")
        print("{} is correctn encoding".format(y))
    except UnicodeDecodeError:
        print("{} is not encoding".format(y))
    except LookupError:
        print("{} is not sutable".format(y))
        l1.append(y)
# Out:
# 646 is not encoding
# ansi_x3.4_1968 is not encoding
# ansi_x3_4_1968 is not encoding
# ansi_x3.4_1986 is not encoding
# cp367 is not encoding
# csascii is not encoding
# ibm367 is not encoding
# iso646_us is not encoding
# iso_646.irv_1991 is not encoding
# iso_ir_6 is not encoding
# us is not encoding
# us_ascii is not encoding
# base64 is not sutable
# base_64 is not sutable
# big5_tw is not encoding
# csbig5 is not encoding
# big5_hkscs is not encoding
# hkscs is not encoding
# bz2 is not sutable
# 037 is correctn encoding
# csibm037 is correctn encoding
# ebcdic_cp_ca is correctn encoding
# ebcdic_cp_nl is correctn encoding
# ebcdic_cp_us is correctn encoding
# ebcdic_cp_wt is correctn encoding
# ibm037 is correctn encoding
# ibm039 is correctn encoding
# 1026 is correctn encoding
# csibm1026 is correctn encoding
# ibm1026 is correctn encoding
# 1125 is correctn encoding
# ibm1125 is correctn encoding
# cp866u is correctn encoding
# ruscii is correctn encoding
# ...

# %%
l1
# Out:
# ['base64',
#  'base_64',
#  'bz2',
#  'hex',
#  'csHPRoman8',
#  'quopri',
#  'quoted_printable',
#  'quotedprintable',
#  'rot13',
#  'uu',
#  'zip',
#  'zlib']

# %%
data = pd.read_csv("spam.csv",encoding = "latin")

# %%
data
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ì_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %%
data.shape
# Out:
# (5572, 5)

# %%
files = pd.read_csv("spam.csv",encoding = "latin",chunksize = 100)

for chunk in files:
    print(chunk.head(2))
    print("*"*50)
# Out:
#     v1                                                 v2 Unnamed: 2  \
# 0  ham  Go until jurong point, crazy.. Available only ...        NaN
# 1  ham                      Ok lar... Joking wif u oni...        NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# **************************************************
#       v1                                                 v2  Unnamed: 2  \
# 100  ham  Okay name ur price as long as its legal! Wen c...         NaN
# 101  ham  I'm still looking for a car to buy. And have n...         NaN
#
#      Unnamed: 3  Unnamed: 4
# 100         NaN         NaN
# 101         NaN         NaN
# **************************************************
#       v1                                                 v2 Unnamed: 2  \
# 200  ham                       I sent you  &lt;#&gt;  bucks        NaN
# 201  ham  Hello darlin ive finished college now so txt m...        NaN
#
#     Unnamed: 3 Unnamed: 4
# ...

# %%
files = pd.read_csv("spam.csv",encoding = "latin",chunksize = 100)
c = 0
for chunk in files:
    print(chunk.head(2))
    print("*"*50)
    c+=1
# Out:
#     v1                                                 v2 Unnamed: 2  \
# 0  ham  Go until jurong point, crazy.. Available only ...        NaN
# 1  ham                      Ok lar... Joking wif u oni...        NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# **************************************************
#       v1                                                 v2  Unnamed: 2  \
# 100  ham  Okay name ur price as long as its legal! Wen c...         NaN
# 101  ham  I'm still looking for a car to buy. And have n...         NaN
#
#      Unnamed: 3  Unnamed: 4
# 100         NaN         NaN
# 101         NaN         NaN
# **************************************************
#       v1                                                 v2 Unnamed: 2  \
# 200  ham                       I sent you  &lt;#&gt;  bucks        NaN
# 201  ham  Hello darlin ive finished college now so txt m...        NaN
#
#     Unnamed: 3 Unnamed: 4
# ...

# %%
c
# Out:
# 56

# %%
import time

# %%
x = time.time()
data1 = pd.read_csv("spam.csv",encoding = "latin")
y = time.time()

# %%
y-x
# Out:
# 0.021105051040649414

# %%
pip install polars
# Out:
# ...
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/35.9 MB ? eta -:--:--
#    ---------------------------------------- 0.4/35.9 MB 2.5 MB/s eta 0:00:15
#    - -------------------------------------- 1.3/35.9 MB 6.9 MB/s eta 0:00:06
#    -- ------------------------------------- 2.1/35.9 MB 8.9 MB/s eta 0:00:04
#    --- ------------------------------------ 3.1/35.9 MB 10.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.3/35.9 MB 12.6 MB/s eta 0:00:03
#    ------ --------------------------------- 5.4/35.9 MB 14.4 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/35.9 MB 15.4 MB/s eta 0:00:02
# ...

# %%
import polars

# %%
x = time.time()
data2 = polars.read_csv("spam.csv",encoding = "latin")
y = time.time()

# %%
y-x
# Out:
# 0.5820145606994629
